# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('PySparkExample.com').getOrCreate()
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x782e7dbe1a90>

# %%
text_data = [
    "Hello this is an example of Spark WordCount Example",
    "we are using PySpark",
    "PySpark is a great tool for Big Data Analysis"
]

text_rdd = spark.sparkContext.parallelize(text_data)

# %%
text_rdd2 = text_rdd.map(lambda x: x.split(" "))
text_rdd2.collect()
# Out:
# [['Hello',
#   'this',
#   'is',
#   'an',
#   'example',
#   'of',
#   'Spark',
#   'WordCount',
#   'Example'],
#  ['we', 'are', 'using', 'PySpark'],
#  ['PySpark', 'is', 'a', 'great', 'tool', 'for', 'Big', 'Data', 'Analysis']]

# %%
text_rdd2_flat = text_rdd.flatMap(lambda x: x.split(" "))
text_rdd2_flat.collect()
# Out:
# ['Hello',
#  'this',
#  'is',
#  'an',
#  'example',
#  'of',
#  'Spark',
#  'WordCount',
#  'Example',
#  'we',
#  'are',
#  'using',
#  'PySpark',
#  'PySpark',
#  'is',
#  'a',
#  'great',
#  'tool',
#  'for',
#  'Big',
#  'Data',
#  'Analysis']
