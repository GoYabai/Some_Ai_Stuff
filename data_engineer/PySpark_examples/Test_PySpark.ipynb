# %%
# !pip install pyspark pyspark[sql]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 58.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.2-py2.py3-none-any.whl size=317812365 sha256=9082afcb069717f071f9ca3d44dab81dcaec7cbd0664121a78a39af1ee75896d
#   Stored in directory: /home/thuannd-ailab/.cache/pip/wheels/9d/29/ee/3a756632ca3f0a6870933bac1c9db6e4af2c068f019aba0ee1
# Successfully built pyspark
# ...

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('PySparkExample.com').getOrCreate()
# Out:
# 24/09/07 11:42:48 WARN Utils: Your hostname, s96gb-WS-C621E-SAGE-Series resolves to a loopback address: 127.0.1.1; using 192.168.1.12 instead (on interface enp5s0)
# 24/09/07 11:42:48 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/07 11:42:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.12:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkExample.com</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read csv

# %%
df_csv = spark.read.csv("./people.csv")
df_csv.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)

# %%
df_csv_header = spark.read.csv("./people.csv" , 
                        header=True)
df_csv_header.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- person_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- date of birth: string (nullable = true)

# %%
df2_csv_schema = spark.read.csv("./people.csv",
                         header=True,
                         inferSchema=True)
df2_csv_schema.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- person_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- date of birth: timestamp (nullable = true)

# %% [markdown]
# ## Read Json

# %%
df_json = spark.read.json("./people.json")
# Out:
# root
#  |-- date of birth: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- person_id: long (nullable = true)
#  |-- sex: string (nullable = true)

# %%
df_json.printSchema()
# Out:
# root
#  |-- date of birth: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- person_id: long (nullable = true)
#  |-- sex: string (nullable = true)

# %%
df_json.show()
# Out:
# +-------------+-----------------+---------+------+
# |date of birth|             name|person_id|   sex|
# +-------------+-----------------+---------+------+
# |   1990-08-31|   Penelope Lewis|      100|female|
# |   1971-10-14|    David Anthony|      101|  male|
# |   1962-05-24|        Ida Shipp|      102|female|
# |   2017-03-10|     Joanna Moore|      103|female|
# |   2020-08-05|   Lisandra Ortiz|      104|female|
# |   1999-12-30|    David Simmons|      105|  male|
# |   1983-05-09|    Edward Hudson|      106|  male|
# |   1990-09-13|     Albert Jones|      107|  male|
# |   1958-08-08| Leonard Cavender|      108|  male|
# |   2005-05-24|   Everett Vadala|      109|  male|
# |   2002-05-07| Freddie Claridge|      110|  male|
# |   1989-07-13|Annabelle Rosseau|      111|female|
# |   1976-01-19|    Eulah Emanuel|      112|female|
# |   1970-05-26|       Shaun Love|      113|  male|
# |   1980-12-22|Alejandro Brennan|      114|  male|
# ...

# %% [markdown]
# ## Read txt

# %%
df_text = spark.read.text("./text_data.txt")

# %%
df_text.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
df_text.show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# | Dữ liệu có cấu trúc|
# |Dữ liệu có cấu tr...|
# |để quản lý và tìm...|
# |lưu trữ và xử lý ...|
# |Các thành phần củ...|
# |cho phép các nhà ...|
# |đơn giản để tìm k...|
# |Dữ liệu phi cấu trúc|
# |Dữ liệu phi cấu t...|
# |hoặc xác định rõ ...|
# |Nó không có cấu t...|
# |Dữ liệu phi cấu t...|
# |tweet, lượt chia ...|
# |video trên YouTub...|
# |Dữ liệu bán cấu trúc|
# |Dữ liệu bán cấu t...|
# |giữa dữ liệu có c...|
# |Email là một ví d...|
# |vì chúng bao gồm ...|
# |cũng như nhiều th...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# ## SQL

# %%
df.createOrReplaceTempView("table") 
result = spark.sql("SELECT * FROM table WHERE age > 30") 
result.show()
